# %% [markdown]
# # Description
# An insurance company has decided to start a breast cancer campaign for raising awareness about breast cancer.
# They feel that the first step for raising awareness is spreading the word about the facts and the statistics of the disease to the public.
# Requirements
# In this part of your project, you are required to:
# Perform exploratory data analysis on the data from the Wisconsin Breast Cancer dataset.
# Visualize the data and show your visualizations.
# Preprocess the dataset to be ready for future work.

# %%
import pandas as pd
df=pd.read_csv('data.csv')
df.dropna
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Preprocessing
# Perform any needed pre-processing on the chosen features, including:
#
# Scaling
#
# Encoding
#
# Dealing with NaN values
#
# Normalization
#
# Note:
# You need to output the result of your pre-processing to an output CSV called “data_refined.csv.”

# %%
#drop unneeded columns
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df=df.drop(columns=['id', 'Unnamed: 32'])

# %%
df=df.rename(columns= {'concave points_worst':'concave_points_worst', 'concave points_mean':'concave_points_mean', 'concave points_se':'concave_points_se'})
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
#X=df.radius_mean
#radius_mean_s = scaler.fit_transform(X)

# %%
import seaborn as sns
sns.heatmap(data= df.corr())
# Out:
# <AxesSubplot:>

# %%
# remove columns with correlation > 0.95 since data is redundant 
import numpy as np

# Create correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# Drop features 
df.drop(to_drop, axis=1, inplace=True)

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# count   569.000000    569.000000       569.000000        569.000000
# mean     14.127292     19.289649         0.096360          0.104341
# std       3.524049      4.301036         0.014064          0.052813
# min       6.981000      9.710000         0.052630          0.019380
# 25%      11.700000     16.170000         0.086370          0.064920
# 50%      13.370000     18.840000         0.095870          0.092630
# 75%      15.780000     21.800000         0.105300          0.130400
# max      28.110000     39.280000         0.163400          0.345400
#
#        concavity_mean  concave_points_mean  symmetry_mean  \
# count      569.000000           569.000000     569.000000
# mean         0.088799             0.048919       0.181162
# std          0.079720             0.038803       0.027414
# min          0.000000             0.000000       0.106000
# 25%          0.029560             0.020310       0.161900
# ...

# %%
sns.heatmap(data= df.corr().abs())
# Out:
# <AxesSubplot:>

# %%
#encode "diagnosis" with label. 0 = benign, 1 = metastatic
df.diagnosis.unique()

from sklearn.preprocessing import LabelEncoder 
enc_label = LabelEncoder()                  
enc_diagnosis=enc_label.fit_transform(df.iloc[:, 0].values)

# %%
#df['diagnosis']=enc_diagnosis.astype(bool)
df['diagnosis']=enc_diagnosis

# %%
df.head(5)
# Out:
#    diagnosis  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0          1        17.99         10.38          0.11840           0.27760
# 1          1        20.57         17.77          0.08474           0.07864
# 2          1        19.69         21.25          0.10960           0.15990
# 3          1        11.42         20.38          0.14250           0.28390
# 4          1        20.29         14.34          0.10030           0.13280
#
#    concavity_mean  concave_points_mean  symmetry_mean  fractal_dimension_mean  \
# 0          0.3001              0.14710         0.2419                 0.07871
# 1          0.0869              0.07017         0.1812                 0.05667
# 2          0.1974              0.12790         0.2069                 0.05999
# 3          0.2414              0.10520         0.2597                 0.09744
# 4          0.1980              0.10430         0.1809                 0.05883
#
# ...

# %%
df.tail(5)
# Out:
#      diagnosis  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 564          1        21.56         22.39          0.11100           0.11590
# 565          1        20.13         28.25          0.09780           0.10340
# 566          1        16.60         28.08          0.08455           0.10230
# 567          1        20.60         29.33          0.11780           0.27700
# 568          0         7.76         24.54          0.05263           0.04362
#
#      concavity_mean  concave_points_mean  symmetry_mean  \
# 564         0.24390              0.13890         0.1726
# 565         0.14400              0.09791         0.1752
# 566         0.09251              0.05302         0.1590
# 567         0.35140              0.15200         0.2397
# 568         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean  radius_se  ...  concave_points_se  symmetry_se  \
# 564                 0.05623     1.1760  ...            0.02454      0.01114
# ...

# %%
#scale all the numerical columns 
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()

x=df.iloc[:,1:24].values
scaled_x=scaler.fit_transform(x)

# %%
x.shape
# Out:
# (569, 23)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
scaled_x
plt.hist(scaled_x)
plt.show()

# %%
plt.plot(scaled_x)
plt.show()

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'smoothness_mean',
#        'compactness_mean', 'concavity_mean', 'concave_points_mean',
#        'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se',
#        'smoothness_se', 'compactness_se', 'concavity_se', 'concave_points_se',
#        'symmetry_se', 'fractal_dimension_se', 'texture_worst',
#        'smoothness_worst', 'compactness_worst', 'concavity_worst',
#        'concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#need to find an easier way to do this part

df['radius_mean']=scaled_x[:,0]
df['texture_mean']= scaled_x[:,1]
df['smoothness_mean']=scaled_x[:,2]
df['compactness_mean']= scaled_x[:,3]
df['concavity_mean']=scaled_x[:,4]
df['concave_points_mean']= scaled_x[:,5]
df['symmetry_mean']=scaled_x[:,6]
df['fractal_dimension_mean']= scaled_x[:,7]
df['radius_se']= scaled_x[:,8]
df['texture_se']= scaled_x[:,9]
df['smoothness_se']= scaled_x[:,10]
df['compactness_se']= scaled_x[:,11]
df['concavity_se']= scaled_x[:,12]
df['concave_points_se']= scaled_x[:,13]
df['symmetry_se']= scaled_x[:,14]
df['fractal_dimension_se']= scaled_x[:,15]
df['texture_worst']= scaled_x[:,16]
df['smoothness_worst']=scaled_x[:,17]
df['compactness_worst']=scaled_x[:,18]
df['concavity_worst']=scaled_x[:,19]
df['concave_points_worst']= scaled_x[:,20]
df['symmetry_worst']=scaled_x[:,21]
df['fractal_dimension_worst']=scaled_x[:,22]

# %%
df.head(5)
# Out:
#    diagnosis  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0          1     1.097064     -2.073335         1.568466          3.283515
# 1          1     1.829821     -0.353632        -0.826962         -0.487072
# 2          1     1.579888      0.456187         0.942210          1.052926
# 3          1    -0.768909      0.253732         3.283553          3.402909
# 4          1     1.750297     -1.151816         0.280372          0.539340
#
#    concavity_mean  concave_points_mean  symmetry_mean  fractal_dimension_mean  \
# 0        2.652874             2.532475       2.217515                2.255747
# 1       -0.023846             0.548144       0.001392               -0.868652
# 2        1.363478             2.037231       0.939685               -0.398008
# 3        1.915897             1.451707       2.867383                4.910919
# 4        1.371011             1.428493      -0.009560               -0.562450
#
# ...

# %%
#export to csv file 
df.to_csv('data_refined.csv', index=False)

# %% [markdown]
# # Visualization
# You need to deliver a number of visualizations for your dataset, including:
#
# Pair plots for the features
#
# Correlation matrix heat map
#
# Box plots for the features
#
# Note:
# Feel free to add the visualizations that you like!

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'smoothness_mean',
#        'compactness_mean', 'concavity_mean', 'concave_points_mean',
#        'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se',
#        'smoothness_se', 'compactness_se', 'concavity_se', 'concave_points_se',
#        'symmetry_se', 'fractal_dimension_se', 'texture_worst',
#        'smoothness_worst', 'compactness_worst', 'concavity_worst',
#        'concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#remove columns where one histogram is almost completely engulfed by the other and the means are similar. 
#signifies that the parameter has minimal effect on diagnosis and wouldnt be significant to the insurance company
        
sns.pairplot(df, vars = ['radius_mean', 'texture_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 
                         'radius_se', 'concave_points_se', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 
                         'symmetry_worst'], hue="diagnosis")

# %%
#including all the features is too slow and cluttered. 

#sns.pairplot(df, vars=['radius_mean', 'texture_mean', 'smoothness_mean',
#       'compactness_mean', 'concavity_mean', 'symmetry_mean',
#       'fractal_dimension_mean', 'radius_se', 'texture_se', 'smoothness_se',
#       'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#       'fractal_dimension_se', 'smoothness_worst', 'compactness_worst',
#       'concavity_worst', 'symmetry_worst', 'fractal_dimension_worst'], hue="diagnosis")

# %%
#heatmap 
sns.heatmap(data= df.corr().abs())
# Out:
# <AxesSubplot:>

# %%
#make some boxplots 
sns.boxplot(x="diagnosis", y="radius_mean", data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='radius_mean'>

# %%
sns.boxplot(x="diagnosis", y="concavity_mean", data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='concavity_mean'>

# %%
sns.boxplot(x="diagnosis", y="concavity_se", data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='concavity_se'>

# %%
sns.boxplot(x="diagnosis", y="concavity_worst", data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='concavity_worst'>

# %% [markdown]
# # Challenge Yourself
#
# Visualize your data in violin plots.
#
# Describe what a violin plot is.
#
# Determine whether or not some of the features have outliers based on your violin plots.

# %%
# a violin plot is like a box plot with a smoothed probability density around the data.
# It shows more than just the statistics of the data 
# outliers are most likely to occur in datasets where the histogram data looks skewed or scatterplot data shows lone points 
sns.violinplot(x="diagnosis", y="concavity_worst", data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='concavity_worst'>

# %%
sns.violinplot(x="diagnosis", y="radius_se", data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='radius_se'>

# %%
#there are likely outliers in the concavity_worst and radius_se data
