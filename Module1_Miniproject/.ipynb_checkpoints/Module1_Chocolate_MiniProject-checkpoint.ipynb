# %% [markdown]
# # Expected Output
# By the end of this mini project, you will need to deliver within your code:
#
# the count of the tuples in the given dataset;
#
# the count of the names of unique company names from the attributes;
#
# the count of reviews in 2013 from the attributes;
#
# the count of missing values in a Specifically given;
#
# an output plot of the histogram of the values in the column named “Ratings;”.
#
# an output plot of the scatter plot between the cocoa percent values against the rating values; and
# the normalized ratings column values.
#
# You are expected to write around 25 lines of code to complete this project.

# %% [markdown]
# # Importing the Data

# %%
#read the data into a dataframe
import pandas as pd
df=pd.read_csv("flavors_of_cacao.csv")

# %%
#inspect the data and perform any required initial data cleaning
df
# Out:
#      Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                      A. Morin                       Agua Grande  1876
# 1                      A. Morin                             Kpime  1676
# 2                      A. Morin                            Atsane  1676
# 3                      A. Morin                             Akata  1680
# 4                      A. Morin                            Quilla  1704
# ...                         ...                               ...   ...
# 1790                     Zotter                              Peru   647
# 1791                     Zotter                             Congo   749
# 1792                     Zotter                      Kerala State   749
# 1793                     Zotter                      Kerala State   781
# 1794                     Zotter                Brazil, Mitzi Blue   486
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# ...

# %%
df.columns
# Out:
# Index(['Company \n(Maker-if known)', 'Specific Bean Origin\nor Bar Name',
#        'REF', 'Review\nDate', 'Cocoa\nPercent', 'Company\nLocation', 'Rating',
#        'Bean\nType', 'Broad Bean\nOrigin'],
#       dtype='object')

# %%
# clean up the column names to remove spaces and extra info

df.columns=['Company', 'SpecificBeanOrigin', 'REF', 'ReviewDate', 'CocoaPercent', 'CompanyLocation', 'Rating',
       'BeanType', 'BroadBeanOrigin']
df.head(6)
# Out:
#     Company SpecificBeanOrigin   REF  ReviewDate CocoaPercent CompanyLocation  \
# 0  A. Morin        Agua Grande  1876        2016          63%          France
# 1  A. Morin              Kpime  1676        2015          70%          France
# 2  A. Morin             Atsane  1676        2015          70%          France
# 3  A. Morin              Akata  1680        2015          70%          France
# 4  A. Morin             Quilla  1704        2015          70%          France
# 5  A. Morin           Carenero  1315        2014          70%          France
#
#    Rating BeanType BroadBeanOrigin
# 0    3.75                 Sao Tome
# 1    2.75                     Togo
# 2    3.00                     Togo
# 3    3.50                     Togo
# 4    3.50                     Peru
# 5    2.75  Criollo       Venezuela

# %% [markdown]
# # Exploring the Dataset

# %%
#how many tuples are in the dataset? 
len(df)
# Out:
# 1795

# %%
#how many unique company names are in the dataset?
len(df.Company.unique())
# Out:
# 416

# %%
#how many reviews are made in 2013 in this dataset?
df.groupby(["ReviewDate"]).count()
# Out:
#             Company  SpecificBeanOrigin  REF  CocoaPercent  CompanyLocation  \
# ReviewDate
# 2006             72                  72   72            72               72
# 2007             77                  77   77            77               77
# 2008             93                  93   93            93               93
# 2009            123                 123  123           123              123
# 2010            111                 111  111           111              111
# 2011            165                 165  165           165              165
# 2012            195                 195  195           195              195
# 2013            184                 184  184           184              184
# 2014            247                 247  247           247              247
# 2015            285                 285  285           285              285
# 2016            219                 219  219           219              219
# ...

# %%
df[df.ReviewDate ==2013]
# Out:
#                Company              SpecificBeanOrigin   REF  ReviewDate  \
# 10            A. Morin                          Panama  1011        2013
# 11            A. Morin                      Madagascar  1011        2013
# 12            A. Morin                          Brazil  1011        2013
# 13            A. Morin                        Equateur  1011        2013
# 14            A. Morin                        Colombie  1015        2013
# ...                ...                             ...   ...         ...
# 1738  Wilkie's Organic                Amazonas w/ nibs  1173        2013
# 1741    Willie's Cacao          Java, Indonesian Black  1109        2013
# 1751         Woodblock  Camino Verde P., Balao, Guayas  1042        2013
# 1752         Woodblock                      Gran Couva  1042        2013
# 1758           Xocolat                      Hispaniola  1057        2013
#
#      CocoaPercent    CompanyLocation  Rating    BeanType     BroadBeanOrigin
# ...

# %%
df["BeanType"][0]
# Out:
# '\xa0'

# %%
df[df.BeanType =='\xa0']
# Out:
#        Company  SpecificBeanOrigin   REF  ReviewDate CocoaPercent  \
# 0     A. Morin         Agua Grande  1876        2016          63%
# 1     A. Morin               Kpime  1676        2015          70%
# 2     A. Morin              Atsane  1676        2015          70%
# 3     A. Morin               Akata  1680        2015          70%
# 4     A. Morin              Quilla  1704        2015          70%
# ...        ...                 ...   ...         ...          ...
# 1787    Zotter       Santo Domingo   879        2012          70%
# 1789    Zotter       Indianer, Raw   883        2012          58%
# 1790    Zotter                Peru   647        2011          70%
# 1793    Zotter        Kerala State   781        2011          62%
# 1794    Zotter  Brazil, Mitzi Blue   486        2010          65%
#
#      CompanyLocation  Rating BeanType     BroadBeanOrigin
# 0             France    3.75                     Sao Tome
# ...

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

ratings = df.Rating.values

plt.figure(figsize=(16,5))
plt.hist(ratings, bins=4, color="red")
plt.xlabel("Ratings")
# Out:
# Text(0.5, 0, 'Ratings')

# %% [markdown]
# # Convert and Visualize

# %%
#change the type of values in the column percent from string values to numerical values
df.head(5)
# Out:
#     Company SpecificBeanOrigin   REF  ReviewDate CocoaPercent CompanyLocation  \
# 0  A. Morin        Agua Grande  1876        2016          63%          France
# 1  A. Morin              Kpime  1676        2015          70%          France
# 2  A. Morin             Atsane  1676        2015          70%          France
# 3  A. Morin              Akata  1680        2015          70%          France
# 4  A. Morin             Quilla  1704        2015          70%          France
#
#    Rating BeanType BroadBeanOrigin
# 0    3.75                 Sao Tome
# 1    2.75                     Togo
# 2    3.00                     Togo
# 3    3.50                     Togo
# 4    3.50                     Peru

# %%
df["CocoaPercent"] = df["CocoaPercent"].str.replace(r'\D',"").astype(int)
df.head(5)
# Out:
# C:\Users\Douglas\AppData\Local\Temp/ipykernel_10968/2848831487.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["CocoaPercent"] = df["CocoaPercent"].str.replace(r'\D',"").astype(int)
#     Company SpecificBeanOrigin   REF  ReviewDate  CocoaPercent  \
# 0  A. Morin        Agua Grande  1876        2016            63
# 1  A. Morin              Kpime  1676        2015            70
# 2  A. Morin             Atsane  1676        2015            70
# 3  A. Morin              Akata  1680        2015            70
# 4  A. Morin             Quilla  1704        2015            70
#
#   CompanyLocation  Rating BeanType BroadBeanOrigin
# 0          France    3.75                 Sao Tome
# 1          France    2.75                     Togo
# 2          France    3.00                     Togo
# 3          France    3.50                     Togo
# 4          France    3.50                     Peru

# %%
#does more cocoa in a bar correspond to a higher rating? 

ratings = df.Rating.values 
percent = df.CocoaPercent.values

plt.figure(figsize=(16,5))
plt.scatter(percent, ratings, color = 'red')
plt.xlabel("Cocoa Percent")
plt.ylabel("Ratings")
# Out:
# Text(0, 0.5, 'Ratings')

# %%
df.describe()
# Out:
#                REF   ReviewDate  CocoaPercent       Rating
# count  1795.000000  1795.000000   1795.000000  1795.000000
# mean   1035.904735  2012.325348     74.192758     3.185933
# std     552.886365     2.927210     40.426829     0.478062
# min       5.000000  2006.000000     42.000000     1.000000
# 25%     576.000000  2010.000000     70.000000     2.875000
# 50%    1069.000000  2013.000000     70.000000     3.250000
# 75%    1502.000000  2015.000000     75.000000     3.500000
# max    1952.000000  2017.000000    735.000000     5.000000

# %%
df.drop(df[df.CocoaPercent > 100]. index, inplace = True)

# %%
ratings = df.Rating.values 
percent = df.CocoaPercent.values

plt.figure(figsize=(16,5))
plt.scatter(percent, ratings, color = 'red', alpha = 0.1)
plt.xlabel("Cocoa Percent")
plt.ylabel("Ratings")
# Out:
# Text(0, 0.5, 'Ratings')

# %%
#does more cocoa in a bar correspond to a higher rating? 

# No distinct relationship

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import StandardScaler 

scaler = StandardScaler()

x=df.iloc[:,6:7].values

x_normalized = scaler.fit_transform(x)

# %%
x_normalized
# Out:
# array([[ 1.1781045 ],
#        [-0.9152628 ],
#        [-0.39192097],
#        ...,
#        [ 0.65476267],
#        [ 0.13142085],
#        [-0.39192097]])

# %% [markdown]
# # Challenge yourself (Optional)
# #list the companies ordered by their average score (over each company's reviews)

# %%
df.groupby("Company")["Rating"].agg(["mean"]).sort_values(by = "mean", ascending = False)
# Out:
#                                           mean
# Company
# Tobago Estate (Pralus)                4.000000
# Heirloom Cacao Preservation (Zokoko)  3.875000
# Ocelot                                3.875000
# Amedei                                3.846154
# Matale                                3.812500
# ...                                        ...
# Ki' Xocolatl                          2.000000
# Majani                                2.000000
# Callebaut                             1.875000
# Machu Picchu Trading Co.              1.875000
# Cote d' Or (Kraft)                    1.000000
#
# [415 rows x 1 columns]

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder 

enc = OrdinalEncoder()

df[["Company", "CompanyLocation"]] = enc.fit_transform(df[["Company", "CompanyLocation"]])

# %%
df
# Out:
#       Company  SpecificBeanOrigin   REF  ReviewDate  CocoaPercent  \
# 0         0.0         Agua Grande  1876        2016            63
# 1         0.0               Kpime  1676        2015            70
# 2         0.0              Atsane  1676        2015            70
# 3         0.0               Akata  1680        2015            70
# 4         0.0              Quilla  1704        2015            70
# ...       ...                 ...   ...         ...           ...
# 1790    409.0                Peru   647        2011            70
# 1791    409.0               Congo   749        2011            65
# 1792    409.0        Kerala State   749        2011            65
# 1793    409.0        Kerala State   781        2011            62
# 1794    409.0  Brazil, Mitzi Blue   486        2010            65
#
#       CompanyLocation  Rating   BeanType BroadBeanOrigin
# 0                18.0    3.75                   Sao Tome
# 1                18.0    2.75                       Togo
# ...
