# %% [markdown]
# # Breast Cancer Campaign

# %% [markdown]
# ## Essential Purpose:
# ## Skills Tested:
#
# Using Pandas to read and explore the dataset.
# Using Scikit-Learn to preprocess the data before training.
# Using Pandas for cleansing un-needed columns.
# Using K-Means in Clustering the data.
#
# The company needs you to cluster the two datasets you have worked on so far into groups using your knowledge of clustering for them to study the best insurance plans for new patients based on what cluster they belong to.
#
# ## You are required to:
# Cluster the data in both the Wisconsin Dataset and the Insurance Dataset.
# Implement different clustering techniques.
# Submission of your project on GitHub is optional. If you choose to manage your project using GitHub, find guidelines for using GitHub here. Ensure you are coding using your Jupyter Notebook – it will be uploaded to GitHub when you perform a GIT push operation.
#
# ## Instructions
# To complete your accumulative project, follow these instructions and write the code in a Jupyter Notebook.
# You are expected to write around 25 lines of code to complete this project.

# %% [markdown]
# ## Reading the Dataset
# Read the two previously read and preprocessed datasets into Pandas Data frames.
# Load the previously pre-processed dataset saved in the csv file “data_refined.csv” into a Pandas Data Frame.
# And
# Also load the following:
# https://www.kaggle.com/mirichoi0218/insurance/download

# %%
import pandas as pd 
import numpy as np

dfI = pd.read_csv('insurance.csv')
dfC = pd.read_csv('data_refined.csv')
dfI.dropna()
dfC.dropna()
# Out:
#      diagnosis  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0            1     1.097064     -2.073335         1.568466          3.283515
# 1            1     1.829821     -0.353632        -0.826962         -0.487072
# 2            1     1.579888      0.456187         0.942210          1.052926
# 3            1    -0.768909      0.253732         3.283553          3.402909
# 4            1     1.750297     -1.151816         0.280372          0.539340
# ..         ...          ...           ...              ...               ...
# 564          1     2.110995      0.721473         1.041842          0.219060
# 565          1     1.704854      2.085134         0.102458         -0.017833
# 566          1     0.702284      2.045574        -0.840484         -0.038680
# 567          1     1.838341      2.336457         1.525767          3.272144
# 568          0    -1.808401      1.221792        -3.112085         -1.150752
#
#      concavity_mean  concave_points_mean  symmetry_mean  \
# 0          2.652874             2.532475       2.217515
# 1         -0.023846             0.548144       0.001392
# 2          1.363478             2.037231       0.939685
# 3          1.915897             1.451707       2.867383
# 4          1.371011             1.428493      -0.009560
# ..              ...                  ...            ...
# 564        1.947285             2.320965      -0.312589
# 565        0.693043             1.263669      -0.217664
# 566        0.046588             0.105777      -0.809117
# 567        3.296944             2.658866       2.137194
# 568       -1.114873            -1.261820      -0.820070
#
#      fractal_dimension_mean  radius_se  ...  concave_points_se  symmetry_se  \
# 0                  2.255747   2.489734  ...           0.660820     1.148757
# 1                 -0.868652   0.499255  ...           0.260162    -0.805450
# 2                 -0.398008   1.228676  ...           1.424827     0.237036
# 3                  4.910919   0.326373  ...           1.115007     4.732680
# 4                 -0.562450   1.270543  ...           1.144205    -0.361092
# ..                      ...        ...  ...                ...          ...
# 564               -0.931027   2.782080  ...           2.067178    -1.138416
# 565               -1.058611   1.300499  ...           0.808431    -0.189161
# 566               -0.895587   0.184892  ...           0.612157    -0.891416
# 567                1.043695   1.157935  ...           0.785721     0.326634
# 568               -0.561032  -0.070279  ...          -1.913447     0.752830
#
#      fractal_dimension_se  texture_worst  smoothness_worst  compactness_worst  \
# 0                0.907083      -1.359293          1.307686           2.616665
# 1               -0.099444      -0.369203         -0.375612          -0.430444
# 2                0.293559      -0.023974          0.527407           1.082932
# 3                2.047511       0.133984          3.394275           3.893397
# 4                0.499328      -1.466770          0.220556          -0.313395
# ..                    ...            ...               ...                ...
# 564              0.167980       0.117700          0.378365          -0.273318
# 565             -0.490556       2.047399         -0.691230          -0.394820
# 566              0.036727       1.374854         -0.809587           0.350735
# 567              0.904057       2.237926          1.430427           3.904848
# 568             -0.382754       0.764190         -1.859019          -1.207552
#
#      concavity_worst  concave_points_worst  symmetry_worst  \
# 0           2.109526              2.296076        2.750622
# 1          -0.146749              1.087084       -0.243890
# 2           0.854974              1.955000        1.152255
# 3           1.989588              2.175786        6.046041
# 4           0.613179              0.729259       -0.868353
# ..               ...                   ...             ...
# 564         0.664512              1.629151       -1.360158
# 565         0.236573              0.733827       -0.531855
# 566         0.326767              0.414069       -1.104549
# 567         3.197605              2.289985        1.919083
# 568        -1.305831             -1.745063       -0.048138
#
#      fractal_dimension_worst
# 0                   1.937015
# 1                   0.281190
# 2                   0.201391
# 3                   4.935010
# 4                  -0.397100
# ..                       ...
# 564                -0.709091
# 565                -0.973978
# 566                -0.318409
# 567                 2.219635
# 568                -0.751207
#
# [569 rows x 24 columns]

# %% [markdown]
# ## Preprocessing
# Perform any needed pre-processing on the chosen features including:
# Scaling.
# Encoding.
# Dealing with Nan values.
# Normalization.

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

encoder.fit(dfI['region'])
dfI['region']= encoder.transform(dfI['region'])

numerical = dfI[["age","bmi","children"]]
categorical = dfI[["sex","smoker"]]
categorical = pd.get_dummies(categorical)
features = pd.concat([numerical, categorical], axis = 1)

from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler() 

numerical=scaler.fit_transform(numerical) 
X=np.concatenate((numerical, categorical.iloc[:,1:3].values), axis=1)
dfI = dfI.rename(columns={'sex': 'sex_female', 'smoker': 'smoker_yes'})
dfI["sex_female"]= categorical.iloc[:,0:1].values
dfI["smoker_yes"]= categorical.iloc[:,3:4].values

# %%
dfI.head()
# Out:
#    age  sex_female     bmi  children  smoker_yes  region      charges
# 0   19           1  27.900         0           1       3  16884.92400
# 1   18           0  33.770         1           0       2   1725.55230
# 2   28           0  33.000         3           0       2   4449.46200
# 3   33           0  22.705         0           0       1  21984.47061
# 4   32           0  28.880         0           0       1   3866.85520

# %%
dfC.head()
# Out:
#    diagnosis  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0          1     1.097064     -2.073335         1.568466          3.283515
# 1          1     1.829821     -0.353632        -0.826962         -0.487072
# 2          1     1.579888      0.456187         0.942210          1.052926
# 3          1    -0.768909      0.253732         3.283553          3.402909
# 4          1     1.750297     -1.151816         0.280372          0.539340
#
#    concavity_mean  concave_points_mean  symmetry_mean  fractal_dimension_mean  \
# 0        2.652874             2.532475       2.217515                2.255747
# 1       -0.023846             0.548144       0.001392               -0.868652
# 2        1.363478             2.037231       0.939685               -0.398008
# 3        1.915897             1.451707       2.867383                4.910919
# 4        1.371011             1.428493      -0.009560               -0.562450
#
#    radius_se  ...  concave_points_se  symmetry_se  fractal_dimension_se  \
# 0   2.489734  ...           0.660820     1.148757              0.907083
# 1   0.499255  ...           0.260162    -0.805450             -0.099444
# 2   1.228676  ...           1.424827     0.237036              0.293559
# 3   0.326373  ...           1.115007     4.732680              2.047511
# 4   1.270543  ...           1.144205    -0.361092              0.499328
#
#    texture_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      -1.359293          1.307686           2.616665         2.109526
# 1      -0.369203         -0.375612          -0.430444        -0.146749
# 2      -0.023974          0.527407           1.082932         0.854974
# 3       0.133984          3.394275           3.893397         1.989588
# 4      -1.466770          0.220556          -0.313395         0.613179
#
#    concave_points_worst  symmetry_worst  fractal_dimension_worst
# 0              2.296076        2.750622                 1.937015
# 1              1.087084       -0.243890                 0.281190
# 2              1.955000        1.152255                 0.201391
# 3              2.175786        6.046041                 4.935010
# 4              0.729259       -0.868353                -0.397100
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Feature Selection
# Look again at the features in both your datasets. Decide if some of the features should be dropped for better clustering.

# %%
# Insurance dataset

# %% [markdown]
# ## Clustering
# Use k-means and Mean-shift to fit your data.
# Get optimal k for k-means using the elbow curve method.
# Try different bandwidth for the mean-shift clustering.

# %% [markdown]
# ## Challenge yourself
# Try a new clustering technique such as the DBSCAN clustering and answer the following question:
# Can DBSCAN be used to cluster datasets such as the ones used in this project?
# If yes, try to implement it on the Breast Cancer dataset.

# %% [markdown]
# ## Upload to Github
